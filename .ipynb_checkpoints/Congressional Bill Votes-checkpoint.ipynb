# %% [markdown]
# # Congressional Votes
# - Pull Voting data by House Rep
# - Join with Bill data on Bill ID
# - Understand relationship between Bill sponsorship with party lines, ...

# %%
from urllib.request import urlopen
import bs4
import requests
from lxml import html
from lxml.cssselect import CSSSelector
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # House Vote Data

# %%
url = 'http://clerk.house.gov/evs/2017/roll699.xml'
source = requests.get(url)
ntree = html.document_fromstring(source.content)

# %%
party = ntree.xpath('//party/text()')
yea = ntree.xpath('//yea-total/text()')
nay = ntree.xpath('//nay-total/text()')
present = ntree.xpath('//present-total/text()')
not_voting = ntree.xpath('//not-voting-total/text()')

party = [*party, 'Total']

# %%
congress = ntree.xpath('//congress/text()')
rollnum = ntree.xpath('//rollcall-num/text()')

congress = [*congress, *congress, *congress, *congress]
rollnum = [*rollnum, *rollnum, *rollnum, *rollnum]

# %%
print(rollnum)
# Out:
# ['699', '699', '699', '699']

# %%
votingdf = pd.DataFrame({'congress':congress, 'rollnum':rollnum, 'party':party, 'yea':yea, 'nay':nay, 'present':present, 'not_voting':not_voting})
votingdf = votingdf[['congress', 'rollnum', 'party', 'yea', 'nay', 'present', 'not_voting']]

# %%
votingdf
# Out:
#   congress rollnum        party  yea  nay present not_voting
# 0      115     699   Republican  224   12       0          3
# 1      115     699   Democratic    0  189       0          4
# 2      115     699  Independent    0    0       0          0
# 3      115     699        Total  224  201       0          7

# %% [markdown]
# # House Bill Data

# %%
bill_url = 'https://www.govinfo.gov/bulkdata/BILLSTATUS/115/hr/BILLSTATUS-115hr1.xml'
bill_source = requests.get(bill_url)
bill_ntree = html.document_fromstring(bill_source.content)

# %%
bill_rollnum = bill_ntree.xpath('//recordedvote/rollnumber/text()')
bill_chamber = bill_ntree.xpath('//recordedvote/chamber/text()')
bill_action = bill_ntree.xpath('//recordedvote/fullactionname/text()')
bill_date = bill_ntree.xpath('//recordedvote/date/text()')

# %%
votingdf = pd.DataFrame({'bill_rollnum':bill_rollnum, 'bill_chamber':bill_chamber, 
                         'bill_action':bill_action, 'bill_date':bill_date})

# %%
votingdf
# Out:
#                                     bill_action bill_chamber  \
# 0   Vote on House Agreeing to the Senate Action        House
# 1                                     FREE TEXT       Senate
# 2                   MOTION TO WAIVE (AMENDMENT)       Senate
# 3                            MOTION TO CONSIDER       Senate
# 4                   Placeholder Text for H42510        House
# 5                   Placeholder Text for H42411        House
# 6                            MOTION TO INSTRUCT       Senate
# 7                            MOTION TO INSTRUCT       Senate
# 8                            MOTION TO INSTRUCT       Senate
# 9                                     FREE TEXT       Senate
# 10  Vote on House Agreeing to the Senate Action        House
# 11  Vote on House Agreeing to the Senate Action        House
# 12                                PASSED SENATE       Senate
# 13                           MOTION TO RECOMMIT       Senate
# 14                           MOTION TO RECOMMIT       Senate
# 15                           MOTION TO RECOMMIT       Senate
# 16                           MOTION TO RECOMMIT       Senate
# 17                           MOTION TO RECOMMIT       Senate
# 18                           MOTION TO RECOMMIT       Senate
# 19                           MOTION TO RECOMMIT       Senate
# 20                           MOTION TO RECOMMIT       Senate
# 21                           MOTION TO RECOMMIT       Senate
# 22                           MOTION TO RECOMMIT       Senate
# 23                           MOTION TO CONSIDER       Senate
# 24                         Passage of a Measure        House
#
#                bill_date bill_rollnum
# 0   2017-12-20T17:56:09Z          699
# 1   2017-12-20T05:33:45Z          323
# 2   2017-12-20T05:13:26Z          322
# 3   2017-12-19T20:46:01Z          321
# 4   2017-12-19T19:28:52Z          692
# 5   2017-12-19T19:20:59Z          691
# 6   2017-12-06T22:51:38Z          309
# 7   2017-12-06T21:30:12Z          308
# 8   2017-12-06T21:02:34Z          307
# 9   2017-12-06T20:22:15Z          306
# 10  2017-12-05T01:55:25Z          654
# 11  2017-12-05T00:05:06Z          653
# 12  2017-12-02T06:51:04Z          303
# 13  2017-12-02T05:36:13Z          300
# 14  2017-12-02T04:08:28Z          297
# 15  2017-12-01T17:37:08Z          292
# 16  2017-12-01T17:23:45Z          291
# 17  2017-12-01T17:01:26Z          290
# 18  2017-11-30T22:34:52Z          289
# 19  2017-11-30T19:59:26Z          288
# 20  2017-11-30T18:14:08Z          287
# 21  2017-11-30T16:52:58Z          286
# 22  2017-11-29T23:19:43Z          285
# 23  2017-11-29T23:17:02Z          284
# 24  2017-11-16T18:49:45Z          637
