# %% [markdown]
# # Congressional Votes
# - Pull Voting data by House Rep
# - Join with Bill data on Bill ID
# - Understand relationship between Bill sponsorship with party lines, ...

# %%
from urllib.request import urlopen
import bs4
import requests
from lxml import html
from lxml.cssselect import CSSSelector
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## House Bill Data
# - Identify bill_action range of values
# -

# %%
xml_range = range(1,5)
bill_rollnum = []
bill_chamber = []
bill_action = []
bill_date = []
bill_voteurl = []

# %%
for i in xml_range:
    bill_url = 'https://www.govinfo.gov/bulkdata/BILLSTATUS/115/hr/BILLSTATUS-115hr' + str(i) + '.xml'
    bill_source = requests.get(bill_url)
    bill_ntree = html.document_fromstring(bill_source.content)
    
    bill_rollnum_text = bill_ntree.xpath('//recordedvote[descendant::chamber/text()="House"]/rollnumber/text()')
    bill_rollnum.append(bill_rollnum_text)
    bill_chamber_text = bill_ntree.xpath('//recordedvote/chamber[text()="House"]/text()')
    bill_chamber.append(bill_chamber_text)
    bill_action_text = bill_ntree.xpath('//recordedvote[descendant::chamber/text()="House"]/fullactionname/text()')
    bill_action.append(bill_action_text)
    bill_date_text = bill_ntree.xpath('//recordedvote[descendant::chamber/text()="House"]/date/text()')
    bill_date.append(bill_date_text)
    bill_voteurl_text = bill_ntree.xpath('//recordedvote[descendant::chamber/text()="House"]/url/text()')
    bill_voteurl.append(bill_voteurl_text)

# %%
bill_rollnumf = [val for sublist in bill_rollnum for val in sublist]
bill_chamberf = [val for sublist in bill_chamber for val in sublist]
bill_actionf = [val for sublist in bill_action for val in sublist]
bill_datef = [val for sublist in bill_date for val in sublist]
bill_voteurlf = [val for sublist in bill_voteurl for val in sublist]

# %%
bill_voteurlf
# Out:
# ['http://clerk.house.gov/evs/2017/roll699.xml',
#  'http://clerk.house.gov/evs/2017/roll692.xml',
#  'http://clerk.house.gov/evs/2017/roll691.xml',
#  'http://clerk.house.gov/evs/2017/roll654.xml',
#  'http://clerk.house.gov/evs/2017/roll653.xml',
#  'http://clerk.house.gov/evs/2017/roll637.xml',
#  'http://clerk.house.gov/evs/2018/roll205.xml',
#  'http://clerk.house.gov/evs/2018/roll204.xml',
#  'http://clerk.house.gov/evs/2018/roll243.xml',
#  'http://clerk.house.gov/evs/2018/roll165.xml',
#  'http://clerk.house.gov/evs/2018/roll164.xml']

# %%
votingdf = pd.DataFrame({'bill_rollnum':bill_rollnumf, 'bill_chamber':bill_chamberf, 'bill_action':bill_actionf, 
                         'bill_date':bill_datef, 'bill_voteurl':bill_voteurlf})

# %%
col_seq = ['bill_date','bill_rollnum','bill_chamber','bill_action','bill_voteurl']
votingdf = votingdf.reindex(columns=col_seq)

# %%
votingdf
# Out:
#                bill_date bill_rollnum bill_chamber  \
# 0   2017-12-20T17:56:09Z          699        House
# 1   2017-12-19T19:28:52Z          692        House
# 2   2017-12-19T19:20:59Z          691        House
# 3   2017-12-05T01:55:25Z          654        House
# 4   2017-12-05T00:05:06Z          653        House
# 5   2017-11-16T18:49:45Z          637        House
# 6   2018-05-18T16:04:34Z          205        House
# 7   2018-05-18T15:57:08Z          204        House
# 8   2018-06-08T01:18:53Z          243        House
# 9   2018-04-27T15:39:30Z          165        House
# 10  2018-04-27T15:31:43Z          164        House
#
#                                           bill_action  \
# 0         Vote on House Agreeing to the Senate Action
# 1                         Placeholder Text for H42510
# 2                         Placeholder Text for H42411
# 3         Vote on House Agreeing to the Senate Action
# 4         Vote on House Agreeing to the Senate Action
# 5                                Passage of a Measure
# 6                                Passage of a Measure
# 7   Motion to Commit/Recommit With Instructions Re...
# 8                                Passage of a Measure
# 9                                Passage of a Measure
# 10  Motion to Commit/Recommit With Instructions Re...
#
#                                    bill_voteurl
# 0   http://clerk.house.gov/evs/2017/roll699.xml
# 1   http://clerk.house.gov/evs/2017/roll692.xml
# 2   http://clerk.house.gov/evs/2017/roll691.xml
# 3   http://clerk.house.gov/evs/2017/roll654.xml
# 4   http://clerk.house.gov/evs/2017/roll653.xml
# 5   http://clerk.house.gov/evs/2017/roll637.xml
# 6   http://clerk.house.gov/evs/2018/roll205.xml
# 7   http://clerk.house.gov/evs/2018/roll204.xml
# 8   http://clerk.house.gov/evs/2018/roll243.xml
# 9   http://clerk.house.gov/evs/2018/roll165.xml
# 10  http://clerk.house.gov/evs/2018/roll164.xml

# %% [markdown]
# # House Vote Data - By Rep

# %%
voteurl_list = votingdf.bill_voteurl.tolist()
vote_legisnum = []
vote_nameid = []
vote_rollnum = []
vote_record = []

# %%
voteurl_list
# Out:
# ['http://clerk.house.gov/evs/2017/roll699.xml',
#  'http://clerk.house.gov/evs/2017/roll692.xml',
#  'http://clerk.house.gov/evs/2017/roll691.xml',
#  'http://clerk.house.gov/evs/2017/roll654.xml',
#  'http://clerk.house.gov/evs/2017/roll653.xml',
#  'http://clerk.house.gov/evs/2017/roll637.xml',
#  'http://clerk.house.gov/evs/2018/roll205.xml',
#  'http://clerk.house.gov/evs/2018/roll204.xml',
#  'http://clerk.house.gov/evs/2018/roll243.xml',
#  'http://clerk.house.gov/evs/2018/roll165.xml',
#  'http://clerk.house.gov/evs/2018/roll164.xml']

# %%
for i in range(1,len(voteurl_list)):
    vote_url = '{}'.format(voteurl_list[i])
    vote_source = requests.get(vote_url)
    vote_ntree = html.document_fromstring(vote_source.content)
    
    vote_legisnum_text = vote_ntree.xpath('//legis-num/text()')
    vote_legisnum.append(vote_legisnum_text)
    vote_rollnum_text = vote_ntree.xpath('//rollcall-num/text()')
    vote_rollnum.append(vote_rollnum_text)
    vote_nameid_text = vote_ntree.xpath('//recorded-vote/legislator/@name-id')
    vote_nameid.append(vote_nameid_text)
    vote_record_text = vote_ntree.xpath('//recorded-vote/vote/text()')
    vote_record.append(vote_record_text)

# %%
votedf = pd.DataFrame({'vote_legisnum':vote_legisnum, 'vote_rollnum':vote_rollnum, 
                       'vote_nameid':vote_nameid, 'vote_record':vote_record})

# %%
col_seq = ['vote_legisnum','vote_rollnum','vote_nameid','vote_record']
votedf = votedf.reindex(columns=col_seq)

# %%
votedf
# Out:
#   vote_legisnum vote_rollnum  \
# 0       [H R 1]        [692]
# 1       [H R 1]        [691]
# 2       [H R 1]        [654]
# 3       [H R 1]        [653]
# 4       [H R 1]        [637]
# 5       [H R 2]        [205]
# 6       [H R 2]        [204]
# 7       [H R 3]        [243]
# 8       [H R 4]        [165]
# 9       [H R 4]        [164]
#
#                                          vote_nameid  \
# 0  [A000374, A000370, A000055, A000371, A000372, ...
# 1  [A000374, A000370, A000055, A000371, A000372, ...
# 2  [A000374, A000370, A000055, A000371, A000372, ...
# 3  [A000374, A000370, A000055, A000371, A000372, ...
# 4  [A000374, A000370, A000055, A000371, A000372, ...
# 5  [A000374, A000370, A000055, A000371, A000372, ...
# 6  [A000374, A000370, A000055, A000371, A000372, ...
# 7  [A000374, A000370, A000055, A000371, A000372, ...
# 8  [A000374, A000370, A000055, A000371, A000372, ...
# 9  [A000374, A000370, A000055, A000371, A000372, ...
#
#                                          vote_record
# 0  [Yea, Nay, Yea, Nay, Yea, Yea, Yea, Yea, Yea, ...
# 1  [Nay, Yea, Nay, Yea, Nay, Nay, Nay, Nay, Nay, ...
# 2  [Nay, Yea, Nay, Yea, Nay, Nay, Nay, Nay, Nay, ...
# 3  [Yea, Nay, Yea, Nay, Yea, Nay, Yea, Yea, Yea, ...
# 4  [Yea, Nay, Yea, Nay, Yea, Yea, Yea, Yea, Yea, ...
# 5  [Yea, Nay, Yea, Nay, Yea, Nay, Yea, Yea, Yea, ...
# 6  [No, Aye, No, Aye, No, No, No, No, No, No, No,...
# 7  [Yea, Nay, Yea, Nay, Yea, Yea, Yea, Yea, Yea, ...
# 8  [Yea, Yea, Yea, Yea, Yea, Nay, Yea, Yea, Yea, ...
# 9  [No, Aye, No, Aye, No, No, No, No, No, No, No,...

# %%
dict1 = {}
dict2 = {}
for i in range(10):
    a = votedf.iloc[i].vote_rollnum
    b = votedf.iloc[i].vote_nameid
    c = votedf.iloc[i].vote_record

    d = list(zip(b, c))
    for x, y in d:
          dict2[x] = y
    
    dict1[str(a)] = dict2

# %%
dict1
# Out:
# {"['164']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['165']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['204']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['205']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['243']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['637']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
# ...
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'},
#  "['692']": {'A000055': 'No',
#   'A000367': 'No',
#   'A000369': 'No',
#   'A000370': 'Aye',
#   'A000371': 'Aye',
#   'A000372': 'No',
#   'A000374': 'No',
#   'A000375': 'No',
#   'B000213': 'No',
#   'B000490': 'Aye',
#   'B000574': 'Aye',
#   'B000755': 'No',
#   'B001227': 'Aye',
#   'B001243': 'Not Voting',
#   'B001248': 'No',
#   'B001250': 'No',
#   'B001251': 'Not Voting',
#   'B001257': 'No',
#   'B001260': 'No',
#   'B001269': 'No',
#   'B001270': 'Aye',
#   'B001273': 'Not Voting',
#   'B001274': 'No',
#   'B001275': 'No',
#   'B001278': 'Aye',
#   'B001281': 'Aye',
#   'B001282': 'No',
#   'B001283': 'Yea',
#   'B001284': 'No',
#   'B001285': 'Aye',
#   'B001286': 'Aye',
#   'B001287': 'Aye',
#   'B001289': 'No',
#   'B001290': 'No',
#   'B001291': 'No',
#   'B001292': 'Aye',
#   'B001293': 'No',
#   'B001294': 'No',
#   'B001295': 'No',
#   'B001296': 'Aye',
#   'B001297': 'No',
#   'B001298': 'No',
#   'B001299': 'No',
#   'B001300': 'Aye',
#   'B001301': 'No',
#   'B001302': 'No',
#   'B001303': 'Aye',
#   'B001304': 'Aye',
#   'B001305': 'No',
#   'C000059': 'No',
#   'C000266': 'No',
#   'C000537': 'Aye',
#   'C000714': 'Nay',
#   'C000754': 'Aye',
#   'C000984': 'Aye',
#   'C001037': 'Aye',
#   'C001038': 'Aye',
#   'C001048': 'No',
#   'C001049': 'Aye',
#   'C001051': 'No',
#   'C001053': 'No',
#   'C001059': 'Aye',
#   'C001061': 'Aye',
#   'C001062': 'No',
#   'C001063': 'Aye',
#   'C001066': 'Aye',
#   'C001067': 'Aye',
#   'C001068': 'Aye',
#   'C001069': 'Aye',
#   'C001072': 'Aye',
#   'C001077': 'No',
#   'C001078': 'Aye',
#   'C001080': 'Aye',
#   'C001084': 'Aye',
#   'C001087': 'No',
#   'C001090': 'Aye',
#   'C001091': 'Aye',
#   'C001092': 'No',
#   'C001093': 'No',
#   'C001094': 'No',
#   'C001096': 'No',
#   'C001097': 'Aye',
#   'C001101': 'Aye',
#   'C001103': 'No',
#   'C001105': 'No',
#   'C001106': 'No',
#   'C001107': 'No',
#   'C001108': 'No',
#   'C001109': 'No',
#   'C001110': 'Aye',
#   'C001111': 'Aye',
#   'C001112': 'Aye',
#   'C001114': 'No',
#   'D000096': 'Aye',
#   'D000191': 'Aye',
#   'D000197': 'Aye',
#   'D000216': 'Aye',
#   'D000399': 'Aye',
#   'D000482': 'Aye',
#   'D000533': 'No',
#   'D000598': 'Aye',
#   'D000600': 'No',
#   'D000604': 'No',
#   'D000610': 'Aye',
#   'D000612': 'Not Voting',
#   'D000614': 'No',
#   'D000615': 'No',
#   'D000616': 'No',
#   'D000617': 'Aye',
#   'D000619': 'No',
#   'D000620': 'Aye',
#   'D000621': 'No',
#   'D000623': 'Aye',
#   'D000624': 'Aye',
#   'D000625': 'No',
#   'D000626': 'No',
#   'D000627': 'Aye',
#   'D000628': 'No',
#   'E000179': 'Aye',
#   'E000215': 'Aye',
#   'E000288': 'Aye',
#   'E000293': 'Aye',
#   'E000294': 'No',
#   'E000296': 'Aye',
#   'E000297': 'Aye',
#   'E000298': 'No',
#   'F000372': 'No',
#   'F000448': 'Yea',
#   'F000449': 'No',
#   'F000450': 'No',
#   'F000454': 'Aye',
#   'F000455': 'Aye',
#   'F000459': 'No',
#   'F000460': 'Yea',
#   'F000461': 'No',
#   'F000462': 'Aye',
#   'F000464': 'No',
#   'F000465': 'No',
#   'F000466': 'No',
#   'G000289': 'No',
#   'G000377': 'No',
#   'G000410': 'Aye',
#   'G000535': 'Aye',
#   'G000546': 'No',
#   'G000551': 'Aye',
#   'G000552': 'No',
#   'G000553': 'Aye',
#   'G000558': 'No',
#   'G000559': 'Aye',
#   'G000560': 'No',
#   'G000563': 'No',
#   'G000565': 'No',
#   'G000566': 'Not Voting',
#   'G000568': 'No',
#   'G000571': 'Aye',
#   'G000574': 'Aye',
#   'G000576': 'No',
#   'G000577': 'No',
#   'G000578': 'No',
#   'G000579': 'No',
#   'G000580': 'No',
#   'G000581': 'Aye',
#   'G000583': 'Aye',
#   'G000584': 'No',
#   'G000585': 'Aye',
#   'H000324': 'Aye',
#   'H000874': 'Aye',
#   'H001036': 'No',
#   'H001038': 'Aye',
#   'H001045': 'Not Voting',
#   'H001047': 'Aye',
#   'H001048': 'No',
#   'H001050': 'Aye',
#   'H001052': 'No',
#   'H001053': 'No',
#   'H001056': 'No',
#   'H001058': 'No',
#   'H001059': 'No',
#   'H001064': 'Aye',
#   'H001065': 'No',
#   'H001067': 'No',
#   'H001068': 'Not Voting',
#   'H001071': 'No',
#   'H001072': 'No',
#   'H001073': 'No',
#   'H001074': 'No',
#   'H001077': 'No',
#   'H001078': 'No',
#   'I000056': 'No',
#   'J000032': 'Aye',
#   'J000126': 'Aye',
#   'J000174': 'No',
#   'J000255': 'Not Voting',
#   'J000288': 'Aye',
#   'J000289': 'No',
#   'J000290': 'No',
#   'J000292': 'No',
#   'J000294': 'Aye',
#   'J000295': 'No',
#   'J000297': 'Not Voting',
#   'J000298': 'Aye',
#   'J000299': 'No',
#   'K000009': 'Aye',
#   'K000188': 'Aye',
#   'K000210': 'No',
#   'K000362': 'No',
#   'K000375': 'Aye',
#   'K000376': 'No',
#   'K000378': 'No',
#   'K000379': 'Aye',
#   'K000380': 'Aye',
#   'K000381': 'Aye',
#   'K000382': 'Not Voting',
#   'K000385': 'Aye',
#   'K000386': 'No',
#   'K000387': 'No',
#   'K000388': 'No',
#   'K000389': 'Aye',
#   'K000390': 'Aye',
#   'K000391': 'Aye',
#   'K000392': 'Not Voting',
#   'L000263': 'Aye',
#   'L000287': 'Not Voting',
#   'L000397': 'Not Voting',
#   'L000480': 'Aye',
#   'L000491': 'No',
#   'L000551': 'Aye',
#   'L000554': 'No',
#   'L000557': 'Aye',
#   'L000559': 'Aye',
#   'L000560': 'Aye',
#   'L000562': 'Aye',
#   'L000563': 'Aye',
#   'L000564': 'No',
#   'L000565': 'Aye',
#   'L000566': 'No',
#   'L000567': 'No',
#   'L000569': 'No',
#   'L000570': 'Aye',
#   'L000573': 'Not Voting',
#   'L000576': 'No',
#   'L000578': 'No',
#   'L000579': 'Aye',
#   'L000580': 'Aye',
#   'L000581': 'Aye',
#   'L000582': 'Aye',
#   'L000583': 'No',
#   'L000584': 'No',
#   'L000585': 'No',
#   'L000586': 'Aye',
#   'L000587': 'No',
#   'L000588': 'Aye',
#   'L000589': 'Yea',
#   'M000087': 'Aye',
#   'M000312': 'Aye',
#   'M001137': 'Aye',
#   'M001143': 'Aye',
#   'M001156': 'No',
#   'M001157': 'No',
#   'M001158': 'No',
#   'M001159': 'No',
#   'M001160': 'Aye',
#   'M001163': 'Aye',
#   'M001165': 'No',
#   'M001166': 'Aye',
#   'M001177': 'No',
#   'M001179': 'No',
#   'M001180': 'No',
#   'M001181': 'No',
#   'M001184': 'No',
#   'M001185': 'Aye',
#   'M001187': 'No',
#   'M001188': 'Aye',
#   'M001189': 'No',
#   'M001190': 'No',
#   'M001193': 'No',
#   'M001194': 'No',
#   'M001195': 'No',
#   'M001196': 'Aye',
#   'M001197': 'No',
#   'M001198': 'No',
#   'M001199': 'No',
#   'M001200': 'Aye',
#   'M001201': 'No',
#   'M001202': 'Aye',
#   'N000002': 'Aye',
#   'N000015': 'Aye',
#   'N000127': 'Aye',
#   'N000179': 'Aye',
#   'N000181': 'No',
#   'N000184': 'Not Voting',
#   'N000188': 'Aye',
#   'N000189': 'No',
#   'N000190': 'No',
#   'O000168': 'No',
#   'O000170': 'Aye',
#   'O000171': 'Aye',
#   'P000034': 'Aye',
#   'P000096': 'Aye',
#   'P000197': 'Aye',
#   'P000258': 'Aye',
#   'P000523': 'Aye',
#   'P000588': 'No',
#   'P000592': 'No',
#   'P000593': 'Aye',
#   'P000594': 'No',
#   'P000597': 'Aye',
#   'P000598': 'Aye',
#   'P000599': 'No',
#   'P000601': 'Not Voting',
#   'P000604': 'Aye',
#   'P000605': 'No',
#   'P000606': 'No',
#   'P000607': 'Aye',
#   'P000608': 'Aye',
#   'P000609': 'No',
#   'P000611': 'No',
#   'P000613': 'Aye',
#   'Q000023': 'Aye',
#   'R000395': 'No',
#   'R000409': 'No',
#   'R000435': 'No',
#   'R000486': 'Aye',
#   'R000487': 'No',
#   'R000515': 'Aye',
#   'R000570': 'Nay',
#   'R000575': 'No',
#   'R000576': 'Not Voting',
#   'R000577': 'Aye',
#   'R000578': 'No',
#   'R000580': 'No',
#   'R000582': 'No',
#   'R000583': 'No',
#   'R000585': 'No',
#   'R000586': 'No',
#   'R000588': 'Aye',
#   'R000591': 'No',
#   'R000592': 'No',
#   'R000593': 'No',
#   'R000597': 'No',
#   'R000598': 'No',
#   'R000599': 'Aye',
#   'R000601': 'No',
#   'R000602': 'Aye',
#   'R000603': 'No',
#   'R000604': 'No',
#   'R000606': 'Aye',
#   'R000607': 'No',
#   'R000608': 'Aye',
#   'R000609': 'No',
#   'S000051': 'No',
#   'S000185': 'Aye',
#   'S000244': 'No',
#   'S000248': 'Aye',
#   'S000250': 'No',
#   'S000344': 'Aye',
#   'S000364': 'No',
#   'S000480': 'Nay',
#   'S000510': 'Aye',
#   'S000522': 'No',
#   'S000583': 'No',
#   'S001145': 'Aye',
#   'S001148': 'No',
#   'S001150': 'Aye',
#   'S001154': 'No',
#   'S001156': 'Not Voting',
#   'S001157': 'Aye',
#   'S001165': 'Not Voting',
#   'S001168': 'Aye',
#   'S001170': 'Aye',
#   'S001172': 'No',
#   'S001175': 'Aye',
#   'S001176': 'No',
#   'S001180': 'Aye',
#   'S001183': 'No',
#   'S001185': 'Not Voting',
#   'S001187': 'No',
#   'S001189': 'No',
#   'S001190': 'Aye',
#   'S001191': 'Aye',
#   'S001192': 'No',
#   'S001193': 'Aye',
#   'S001195': 'No',
#   'S001196': 'No',
#   'S001199': 'No',
#   'S001200': 'Aye',
#   'S001201': 'Aye',
#   'T000193': 'Aye',
#   'T000238': 'No',
#   'T000460': 'Aye',
#   'T000462': 'Yea',
#   'T000463': 'No',
#   'T000465': 'Aye',
#   'T000467': 'No',
#   'T000468': 'Aye',
#   'T000469': 'Aye',
#   'T000470': 'No',
#   'T000472': 'Aye',
#   'T000474': 'Aye',
#   'T000475': 'No',
#   'T000477': 'No',
#   'T000478': 'No',
#   'U000031': 'No',
#   'V000081': 'Aye',
#   'V000108': 'Aye',
#   'V000129': 'No',
#   'V000130': 'Aye',
#   'V000131': 'Aye',
#   'V000132': 'Aye',
#   'W000187': 'Aye',
#   'W000791': 'No',
#   'W000795': 'No',
#   'W000797': 'Aye',
#   'W000798': 'No',
#   'W000799': 'Not Voting',
#   'W000800': 'Aye',
#   'W000804': 'No',
#   'W000806': 'No',
#   'W000808': 'Not Voting',
#   'W000809': 'No',
#   'W000810': 'No',
#   'W000812': 'No',
#   'W000813': 'No',
#   'W000814': 'No',
#   'W000815': 'No',
#   'W000816': 'No',
#   'W000819': 'No',
#   'W000820': 'No',
#   'W000821': 'No',
#   'W000822': 'Aye',
#   'Y000033': 'Not Voting',
#   'Y000062': 'Aye',
#   'Y000063': 'No',
#   'Y000065': 'No',
#   'Y000066': 'No',
#   'Z000017': 'No'}}

# %%
dict1.keys()
# Out:
# dict_keys(["['692']", "['691']", "['654']", "['653']", "['637']", "['205']", "['204']", "['243']", "['165']", "['164']"])

# %% [markdown]
# ### Data Schema
# BILL OBJECT
# - Legis Number
# - Policy Area
# - By Primary Sponsor
# - By Party
# - By State
# - Date Proposed
# - Date Passed
#
# VOTE OBJECT
# - Legis Number
# - Roll Number
# - Congressman
# - Vote Record
# - Date Roll Call Vote
#
# CONGRESSMAN OBJECT
# - Name
# - Party
# - State
# - District
# - Townname
#
# ### Data Query Requirements
# - What is the voting record by Congressman? Filter by Congressman, Policy Area
# - How bipartisan is each Congressman? Filter by votes given bill sponsorship
# - What's the process for bill passage? % passed, # roll calls, length of time
# - How 'active' / 'influential' is each Congressman?
# -

# %%
from sqlite3 import dbapi2 as sq3
import os
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(os.path.join(PATHSTART, dbfile))
    return sqlite_db

# %%
def init_db(dbfile, schema):
    """Creates the database tables."""
    db = get_db(dbfile)
    db.cursor().executescript(schema)
    db.commit()
    return db

# %%
ourschema="""
DROP TABLE IF EXISTS "candidates";
DROP TABLE IF EXISTS "contributors";
CREATE TABLE "candidates" (
    "id" INTEGER PRIMARY KEY  NOT NULL ,
    "first_name" VARCHAR,
    "last_name" VARCHAR,
    "middle_name" VARCHAR,
    "party" VARCHAR NOT NULL
);
CREATE TABLE "contributors" (
    "id" INTEGER PRIMARY KEY  AUTOINCREMENT  NOT NULL,
    "last_name" VARCHAR,
    "first_name" VARCHAR,
    "middle_name" VARCHAR,
    "street_1" VARCHAR,
    "street_2" VARCHAR,
    "city" VARCHAR,
    "state" VARCHAR,
    "zip" VARCHAR,
    "amount" INTEGER,
    "date" DATETIME,
    "candidate_id" INTEGER NOT NULL,
    FOREIGN KEY(candidate_id) REFERENCES candidates(id)
);
"""

# %%
dfcand=pd.read_csv("./candidates.txt", sep='|')
dfcand.head()
# Out:
#    id   first_name  last_name middle_name party
# 0  33       Joseph      Biden         NaN     D
# 1  36       Samuel  Brownback         NaN     R
# 2  34      Hillary    Clinton          R.     D
# 3  39  Christopher       Dodd          J.     D
# 4  26         John    Edwards         NaN     D

# %%
dfcwci=pd.read_csv("./contributors_with_candidate_id.txt", sep="|")
dfcwci.head()
# Out:
#    id last_name first_name middle_name                street_1 street_2  \
# 0 NaN      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4 NaN      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091   500.0  2007-06-30            16
# 1   Pleasanton    CA  94566   250.0  2007-05-16            16
# 2   Pleasanton    CA  94566    50.0  2007-06-18            16
# 3   Pleasanton    CA  94566   100.0  2007-06-21            16
# 4  Bentonville    AR  72712   100.0  2007-06-16            16

# %%
db=init_db("cancont.db", ourschema)

# %%
dfcand.to_sql("candidates", db, if_exists="append", index=False)

# %%
dfcwci.to_sql("contributors", db, if_exists="append", index=False)

# %%
sel="""
SELECT * FROM candidates;
"""
c=db.cursor().execute(sel)

# %%
c.fetchall()
# Out:
# [(16, 'Mike', 'Huckabee', None, 'R'),
#  (20, 'Barack', 'Obama', None, 'D'),
#  (22, 'Rudolph', 'Giuliani', None, 'R'),
#  (24, 'Mike', 'Gravel', None, 'D'),
#  (26, 'John', 'Edwards', None, 'D'),
#  (29, 'Bill', 'Richardson', None, 'D'),
#  (30, 'Duncan', 'Hunter', None, 'R'),
#  (31, 'Dennis', 'Kucinich', None, 'D'),
#  (32, 'Ron', 'Paul', None, 'R'),
#  (33, 'Joseph', 'Biden', None, 'D'),
#  (34, 'Hillary', 'Clinton', 'R.', 'D'),
#  (35, 'Mitt', 'Romney', None, 'R'),
#  (36, 'Samuel', 'Brownback', None, 'R'),
#  (37, 'John', 'McCain', None, 'R'),
#  (38, 'Tom', 'Tancredo', None, 'R'),
#  (39, 'Christopher', 'Dodd', 'J.', 'D'),
#  (41, 'Fred', 'Thompson', 'D.', 'R')]

# %%
def make_query(sel):
    c=db.cursor().execute(sel)
    return c.fetchall()

# %%
cont_cols = [e[1] for e in make_query("PRAGMA table_info(contributors);")]
cont_cols

def make_frame(list_of_tuples, legend=cont_cols):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
    return pd.DataFrame.from_items(framelist)

# %%
make_query("SELECT * FROM contributors;")
# Out:
# [(1,
#   'Agee',
#   'Steven',
#   None,
#   '549 Laurel Branch Road',
#   None,
#   'Floyd',
#   'VA',
#   '24091',
#   500,
#   '2007-06-30',
#   16),
#  (2,
#   'Ahrens',
#   'Don',
#   None,
#   '4034 Rennellwood Way',
#   None,
#   'Pleasanton',
#   'CA',
#   '94566',
#   250,
#   '2007-05-16',
#   16),
#  (3,
#   'Ahrens',
#   'Don',
#   None,
#   '4034 Rennellwood Way',
#   None,
#   'Pleasanton',
#   'CA',
#   '94566',
#   50,
#   '2007-06-18',
#   16),
#  (4,
#   'Ahrens',
#   'Don',
#   None,
#   '4034 Rennellwood Way',
#   None,
#   'Pleasanton',
#   'CA',
#   '94566',
#   100,
#   '2007-06-21',
#   16),
#  (5,
#   'Akin',
#   'Charles',
#   None,
#   '10187 Sugar Creek Road',
#   None,
#   'Bentonville',
#   'AR',
#   '72712',
#   100,
#   '2007-06-16',
#   16),
#  (6,
#   'Akin',
#   'Mike',
#   None,
#   '181 Baywood Lane',
#   None,
#   'Monticello',
#   'AR',
#   '71655',
#   1500,
#   '2007-05-18',
#   16),
#  (7,
#   'Akin',
#   'Rebecca',
#   None,
#   '181 Baywood Lane',
#   None,
#   'Monticello',
#   'AR',
#   '71655',
#   500,
#   '2007-05-18',
#   16),
#  (8,
#   'Aldridge',
#   'Brittni',
#   None,
#   '808 Capitol Square Place, SW',
#   None,
#   'Washington',
#   'DC',
#   '20024',
#   250,
#   '2007-06-06',
#   16),
#  (9,
#   'Allen',
#   'John D.',
#   None,
#   '1052 Cannon Mill Drive',
#   None,
#   'North Augusta',
#   'SC',
#   '29860',
#   1000,
#   '2007-06-11',
#   16),
#  (10,
#   'Allen',
#   'John D.',
#   None,
#   '1052 Cannon Mill Drive',
#   None,
#   'North Augusta',
#   'SC',
#   '29860',
#   1300,
#   '2007-06-29',
#   16),
#  (11,
#   'Allison',
#   'John W.',
#   None,
#   'P.O. Box 1089',
#   None,
#   'Conway',
#   'AR',
#   '72033',
#   1000,
#   '2007-05-18',
#   16),
#  (12,
#   'Allison',
#   'Rebecca',
#   None,
#   '3206 Summit Court',
#   None,
#   'Little Rock',
#   'AR',
#   '72227',
#   1000,
#   '2007-04-25',
#   16),
#  (13,
#   'Allison',
#   'Rebecca',
#   None,
#   '3206 Summit Court',
#   None,
#   'Little Rock',
#   'AR',
#   '72227',
#   200,
#   '2007-06-12',
#   16),
#  (14,
#   'Altes',
#   'R.D.',
#   None,
#   '8600 Moody Road',
#   None,
#   'Fort Smith',
#   'AR',
#   '72903',
#   2300,
#   '2007-06-21',
#   16),
#  (15,
#   'Andres',
#   'Dale',
#   None,
#   '1160 Glen Oaks Drive',
#   None,
#   'West Des Moines',
#   'IA',
#   '50266',
#   250,
#   '2007-06-06',
#   16),
#  (16,
#   'Anthony',
#   'John',
#   None,
#   '211 Long Island Drive',
#   None,
#   'Hot Springs',
#   'AR',
#   '71913',
#   2300,
#   '2007-06-12',
#   16),
#  (17,
#   'Arbogast',
#   'Robert',
#   None,
#   '12900 State Route 56 SE',
#   None,
#   'Mount Sterling',
#   'OH',
#   '43143',
#   500,
#   '2007-04-08',
#   16),
#  (18,
#   'Arbogast',
#   'Robert',
#   None,
#   '12900 State Route 56 SE',
#   None,
#   'Mount Sterling',
#   'OH',
#   '43143',
#   100,
#   '2007-06-22',
#   16),
#  (19,
#   'Ardle',
#   'William',
#   None,
#   '412 Dakota Avenue',
#   None,
#   'Springfield',
#   'OH',
#   '45504',
#   50,
#   '2007-06-28',
#   16),
#  (20,
#   'Atiq',
#   'Omar',
#   None,
#   '7200 S Hazel Street',
#   None,
#   'Pine Bluff',
#   'AR',
#   '71603',
#   1000,
#   '2007-05-18',
#   16),
#  (21,
#   'Atiq',
#   'Omar',
#   None,
#   '7200 S Hazel Street',
#   None,
#   'Pine Bluff',
#   'AR',
#   '71603',
#   1000,
#   '2007-06-27',
#   16),
#  (22,
#   'Baker',
#   'David',
#   None,
#   '2550 Adamsbrooke Drive',
#   None,
#   'Conway',
#   'AR',
#   '72034',
#   2300,
#   '2007-04-11',
#   16),
#  (23,
#   'Bancroft',
#   'David',
#   None,
#   '2934 Broderick Street',
#   None,
#   'San Francisco',
#   'CA',
#   '94123',
#   250,
#   '2007-04-24',
#   16),
#  (24,
#   'Banks',
#   'Charles',
#   None,
#   'P.O. Box 251310',
#   None,
#   'Little Rock',
#   'AR',
#   '72225',
#   1000,
#   '2007-05-14',
#   16),
#  (25,
#   'Barbee',
#   'John',
#   None,
#   '516 Kellyridge Drive',
#   None,
#   'Apex',
#   'NC',
#   '27502',
#   500,
#   '2007-05-23',
#   16),
#  (26,
#   'Buckler',
#   'Steve',
#   None,
#   '24351 Armada Dr',
#   None,
#   'Dana Point',
#   'CA',
#   '926291306',
#   50,
#   '2007-07-30',
#   20),
#  (27,
#   'Buckler',
#   'Steve',
#   None,
#   '24351 Armada Dr',
#   None,
#   'Dana Point',
#   'CA',
#   '926291306',
#   25,
#   '2007-08-16',
#   20),
#  (28,
#   'Buckheit',
#   'Bruce',
#   None,
#   '8904 KAREN DR',
#   None,
#   'FAIRFAX',
#   'VA',
#   '220312731',
#   100,
#   '2007-09-19',
#   20),
#  (29,
#   'Buckel',
#   'Linda',
#   None,
#   'PO Box 683130',
#   None,
#   'Park City',
#   'UT',
#   '840683130',
#   2300,
#   '2007-08-14',
#   20),
#  (30,
#   'Buckel',
#   'Linda',
#   None,
#   'PO Box 683130',
#   None,
#   'Park City',
#   'UT',
#   '840683130',
#   -2300,
#   '2007-08-14',
#   20),
#  (31,
#   'Buckel',
#   'Linda',
#   None,
#   'PO Box 683130',
#   None,
#   'Park City',
#   'UT',
#   '840683130',
#   4600,
#   '2007-08-14',
#   20),
#  (32,
#   'Buck',
#   'Thomas',
#   None,
#   '4206 Terrace Street',
#   None,
#   'Kansas City',
#   'MO',
#   '64111',
#   100,
#   '2007-09-25',
#   20),
#  (33,
#   'Buck',
#   'Jay',
#   'K.',
#   '1855 Old Willow Rd Unit 322',
#   None,
#   'Northfield',
#   'IL',
#   '600932918',
#   200,
#   '2007-09-12',
#   20),
#  (34,
#   'Buck',
#   'Blaine',
#   'M',
#   '45 Eaton Ave',
#   None,
#   'Camden',
#   'ME',
#   '48431752',
#   2300,
#   '2007-09-30',
#   20),
#  (35,
#   'Buck',
#   'Barbara',
#   None,
#   '1780 NE 138th St',
#   None,
#   'North Miami',
#   'FL',
#   '331811316',
#   50,
#   '2007-09-13',
#   20),
#  (36,
#   'Buck',
#   'Barbara',
#   None,
#   '1780 NE 138th St',
#   None,
#   'North Miami',
#   'FL',
#   '331811316',
#   50,
#   '2007-07-19',
#   20),
#  (37,
#   'Buchman',
#   'Mark M',
#   None,
#   '2530 Lawton Ave',
#   None,
#   'San Luis Obispo',
#   'CA',
#   '934015622',
#   460.8,
#   '2007-07-18',
#   20),
#  (38,
#   'Bucher',
#   'Ida',
#   'M',
#   '1400 Warnall Ave',
#   None,
#   'Los Angeles',
#   'CA',
#   '900245333',
#   100,
#   '2007-07-10',
#   20),
#  (39,
#   'Buchanek',
#   'Elizabeth',
#   None,
#   '7917 Kentbury Dr',
#   None,
#   'Bethesda',
#   'MD',
#   '208144615',
#   50,
#   '2007-09-30',
#   20),
#  (40,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   500,
#   '2007-09-24',
#   20),
#  (41,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   -500,
#   '2007-09-24',
#   20),
#  (42,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   500,
#   '2007-09-24',
#   20),
#  (43,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   700,
#   '2007-08-28',
#   20),
#  (44,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   -700,
#   '2007-08-28',
#   20),
#  (45,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   1000,
#   '2007-08-28',
#   20),
#  (46,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   1300,
#   '2007-08-09',
#   20),
#  (47,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   200,
#   '2007-08-14',
#   20),
#  (48,
#   'Buchanan',
#   'John',
#   None,
#   '2025 NW 29th Rd',
#   None,
#   'Boca Raton',
#   'FL',
#   '334316303',
#   500,
#   '2007-07-25',
#   20),
#  (49,
#   'Buchanan',
#   'John',
#   None,
#   '4635 49th St NW',
#   None,
#   'Washington',
#   'DC',
#   '200164320',
#   200.09,
#   '2007-09-23',
#   20),
#  (50,
#   'Harrison',
#   'Ryan',
#   None,
#   '2247 3rd St',
#   None,
#   'La Verne',
#   'CA',
#   '917504918',
#   25,
#   '2007-07-26',
#   20),
#  (51,
#   'BYNUM',
#   'HERBERT',
#   None,
#   '332 SUNNYSIDE ROAD',
#   None,
#   'TAMPA',
#   'FL',
#   '336177249',
#   -500,
#   '2008-03-10',
#   22),
#  (52,
#   'BYINGTON',
#   'MARGARET',
#   'E.',
#   '2633 MIDDLEBORO LANE N.E.',
#   None,
#   'GRAND RAPIDS',
#   'MI',
#   '495061254',
#   -2300,
#   '2008-03-03',
#   22),
#  (53,
#   'BYERS',
#   'BOB',
#   'A.',
#   '13170 TELFAIR AVENUE',
#   None,
#   'SYLMAR',
#   'CA',
#   '913423573',
#   -2300,
#   '2008-03-07',
#   22),
#  (54,
#   'BYERS',
#   'AUDREY',
#   None,
#   '2658 LADBROOK WAY',
#   None,
#   'THOUSAND OAKS',
#   'CA',
#   '913615073',
#   -200,
#   '2008-03-07',
#   22),
#  (55,
#   'BUSH',
#   'KRYSTIE',
#   None,
#   'P.O. BOX 61046',
#   None,
#   'DENVER',
#   'CO',
#   '802061046',
#   -2300,
#   '2008-03-06',
#   22),
#  (56,
#   'BUSH',
#   'ERIC',
#   None,
#   'P.O. BOX 61046',
#   None,
#   'DENVER',
#   'CO',
#   '802061046',
#   -2300,
#   '2008-03-06',
#   22),
#  (57,
#   'BURTON',
#   'SUSAN',
#   None,
#   '9338 DEER CREEK DRIVE',
#   None,
#   'TAMPA',
#   'FL',
#   '336472286',
#   -2300,
#   '2008-03-05',
#   22),
#  (58,
#   'BURTON',
#   'STEVEN',
#   'G.',
#   '9938 DEER CREEK DRIVE',
#   None,
#   'TAMPA',
#   'FL',
#   '33647',
#   -2300,
#   '2008-03-05',
#   22),
#  (59,
#   'BURTON',
#   'GLENN',
#   'M.',
#   '4404 CHARLESTON COURT',
#   None,
#   'TAMPA',
#   'FL',
#   '336092620',
#   -2300,
#   '2008-03-05',
#   22),
#  (60,
#   'BURKHARDT',
#   'CRAIG',
#   'S.',
#   '910 15TH STREET N.W.',
#   None,
#   'WASHINGTON',
#   'DC',
#   '200052503',
#   -500,
#   '2008-03-07',
#   22),
#  (61,
#   'BURKHARDT',
#   'CRAIG',
#   'S.',
#   '910 15TH STREET N.W.',
#   None,
#   'WASHINGTON',
#   'DC',
#   '200052503',
#   -1000,
#   '2008-03-07',
#   22),
#  (62,
#   'BURKHARDT',
#   'BARBARA',
#   None,
#   '910 15TH STREET N.W.',
#   None,
#   'WASHINGTON',
#   'DC',
#   '200052503',
#   -500,
#   '2008-03-07',
#   22),
#  (63,
#   'BURKE',
#   'SUZANNE',
#   'M.',
#   '3401 EVANSTON',
#   None,
#   'SEATTLE',
#   'WA',
#   '981038677',
#   -700,
#   '2008-03-05',
#   22),
#  (64,
#   'BURKE',
#   'GAIL',
#   None,
#   '165 E. 32ND STREET',
#   'APARTMENT 9E',
#   'NEW YORK',
#   'NY',
#   '100166014',
#   -2000,
#   '2008-03-05',
#   22),
#  (65,
#   'BURKE',
#   'DONALD',
#   'J.',
#   '12 LOMPOC',
#   None,
#   'RANCHO SANTA MARGA',
#   'CA',
#   '926881817',
#   -2300,
#   '2008-03-11',
#   22),
#  (66,
#   'BURGERT',
#   'RONALD',
#   'L.',
#   '5723 PLUMTREE DRIVE',
#   None,
#   'DALLAS',
#   'TX',
#   '752524926',
#   -1000,
#   '2008-03-05',
#   22),
#  (67,
#   'BULL',
#   'BARTLE',
#   'B.',
#   '439 E. 51ST STREET',
#   None,
#   'NEW YORK',
#   'NY',
#   '100226473',
#   -800,
#   '2008-03-10',
#   22),
#  (68,
#   'BULL',
#   'BARTLE',
#   'B.',
#   '439 E. 51ST STREET',
#   None,
#   'NEW YORK',
#   'NY',
#   '100226473',
#   -1000,
#   '2008-03-10',
#   22),
#  (69,
#   'BUKOWSKI',
#   'DANIEL',
#   'J.',
#   '702 S. WRIGHT STREET',
#   None,
#   'NAPERVILLE',
#   'IL',
#   '605406736',
#   -100,
#   '2008-03-10',
#   22),
#  (70,
#   'BUISSON',
#   'MARGARET',
#   'A.',
#   'P.O. BOX 197029',
#   None,
#   'LOUISVILLE',
#   'KY',
#   '402597029',
#   -200,
#   '2008-03-11',
#   22),
#  (71,
#   'BUCKLEY',
#   'WALTER',
#   'W.',
#   '1635 COUNTRY ROAD',
#   None,
#   'BETHLEHEM',
#   'PA',
#   '180155718',
#   -100,
#   '2008-03-05',
#   22),
#  (72,
#   'BUCKLEY',
#   'MARJORIE',
#   'B.',
#   '1635 COUNTRY ROAD',
#   None,
#   'BETHLEHEM',
#   'PA',
#   '180155718',
#   -100,
#   '2008-03-05',
#   22),
#  (73,
#   'BRUNO',
#   'JOHN',
#   None,
#   '10136 WINDERMERE CHASE BLVD.',
#   None,
#   'GOTHA',
#   'FL',
#   '347344707',
#   -2300,
#   '2008-03-06',
#   22),
#  (74,
#   'BRUNO',
#   'IRENE',
#   None,
#   '10136 WINDERMERE CHASE BLVD.',
#   None,
#   'GOTHA',
#   'FL',
#   '347344707',
#   -2300,
#   '2008-03-06',
#   22),
#  (75,
#   'BROWN',
#   'TIMOTHY',
#   'J.',
#   '26826 MARLOWE COURT',
#   None,
#   'STEVENSON RANCH',
#   'CA',
#   '913811020',
#   -2300,
#   '2008-03-06',
#   22),
#  (76,
#   'Schuff',
#   'Bryan',
#   None,
#   '1700 W Sweden Rd',
#   None,
#   'Brockport',
#   'NY',
#   '14420',
#   -25,
#   '2008-08-22',
#   32),
#  (77,
#   'Hobbs',
#   'James',
#   None,
#   '229 Cherry Lane',
#   None,
#   'White House',
#   'TN',
#   '37188',
#   -25,
#   '2008-08-19',
#   32),
#  (78,
#   'Ranganath',
#   'Anoop',
#   None,
#   '2507 Willard Drive',
#   None,
#   'Charlottesville',
#   'VA',
#   '22903',
#   -100,
#   '2008-04-21',
#   32),
#  (79,
#   'Nystrom',
#   'Michael',
#   'A',
#   '93A Fairmont Street',
#   None,
#   'Arlington',
#   'MA',
#   '2474',
#   -503,
#   '2008-04-21',
#   32),
#  (80,
#   'Muse',
#   'Nina',
#   'Jo',
#   '2915 Toro Canyon Rd',
#   None,
#   'Austin',
#   'TX',
#   '78746',
#   -50,
#   '2008-04-21',
#   32),
#  (81,
#   'Waddell',
#   'James',
#   'L.',
#   '1823 Spel Lane SW',
#   None,
#   'Rochester',
#   'MN',
#   '55902',
#   -28,
#   '2008-04-21',
#   32),
#  (82,
#   'Brucks',
#   'William',
#   'C.',
#   'PO Box 391',
#   None,
#   'Corona del Mar',
#   'CA',
#   '92625',
#   -150,
#   '2008-04-21',
#   32),
#  (83,
#   'Kuehn',
#   'David',
#   None,
#   '14502 West 93rd Street',
#   None,
#   'Lenexa',
#   'KS',
#   '66215',
#   -330,
#   '2008-04-21',
#   32),
#  (84,
#   'Verster',
#   'Jeanette',
#   'M.',
#   '7220 SW 61st St',
#   None,
#   'Miami',
#   'FL',
#   '331431807',
#   -1000,
#   '2008-04-21',
#   32),
#  (85,
#   'Uihlein',
#   'Richard',
#   None,
#   '1396 N Waukegan Rd',
#   None,
#   'Lake Forest',
#   'IL',
#   '600451147',
#   -2300,
#   '2008-04-21',
#   32),
#  (86,
#   'Eskenberry',
#   'Robert',
#   'P',
#   '10960 Gray Cir',
#   None,
#   'Westminster',
#   'CO',
#   '80020',
#   -223,
#   '2008-04-21',
#   32),
#  (87,
#   'Froehling',
#   'Alan',
#   'L.',
#   '302 Broadway St',
#   None,
#   'Mount Vernon',
#   'IL',
#   '628645116',
#   -844.8,
#   '2008-04-21',
#   32),
#  (88,
#   'Duryea',
#   'Marcia',
#   'A.',
#   '123 Bayview Ave',
#   None,
#   'Amityville',
#   'NY',
#   '11701',
#   -299.5,
#   '2008-04-21',
#   32),
#  (89,
#   'Perreault',
#   'Louise',
#   None,
#   '503 Brockridge Hunt Drive',
#   None,
#   'Hampton',
#   'VA',
#   '23666',
#   -34.08,
#   '2008-04-21',
#   32),
#  (90,
#   'Rozenfeld',
#   'Timur',
#   None,
#   '57 Herbert Road',
#   None,
#   'Robbinsville',
#   'NJ',
#   '8691',
#   -777.95,
#   '2008-04-21',
#   32),
#  (91,
#   'Kazor',
#   'Christopher',
#   'M',
#   '707 Spindletree ave',
#   None,
#   'Naperville',
#   'IL',
#   '60565',
#   -2592,
#   '2008-04-21',
#   32),
#  (92,
#   'Lehner',
#   'Thomas',
#   'S.',
#   '2701 Star Lane',
#   None,
#   'Wadsworth',
#   'OH',
#   '44281',
#   -200,
#   '2008-04-21',
#   32),
#  (93,
#   'Plummer',
#   'Joseph',
#   None,
#   '587 Blake Hill Rd',
#   None,
#   'New Hampton',
#   'NH',
#   '32564424',
#   -24.6,
#   '2008-04-21',
#   32),
#  (94,
#   'Raught',
#   'Philip',
#   'M',
#   '4714 Plum Way',
#   None,
#   'Pittsburgh',
#   'PA',
#   '15201',
#   -1046,
#   '2008-04-21',
#   32),
#  (95,
#   'Ferrara',
#   'Judith',
#   'D',
#   '1508 Waterford Road',
#   None,
#   'Yardley',
#   'PA',
#   '19067',
#   -1100,
#   '2008-04-21',
#   32),
#  (96,
#   'Johnson',
#   'Cathleen',
#   'E.',
#   '1003 Justin Ln Apt 2016',
#   None,
#   'Austin',
#   'TX',
#   '787572648',
#   -14.76,
#   '2008-04-21',
#   32),
#  (97,
#   'Sanford',
#   'Bradley',
#   None,
#   '940 Post St #43',
#   None,
#   'San Francisco',
#   'CA',
#   '94109',
#   -24.53,
#   '2008-04-21',
#   32),
#  (98,
#   'Gaarder',
#   'Bruce',
#   None,
#   'PO Box 4085',
#   None,
#   'Mountain Home AFB',
#   'ID',
#   '83648',
#   -261,
#   '2008-04-21',
#   32),
#  (99,
#   'Choe',
#   'Hyeokchan',
#   None,
#   '207 Bridle Way',
#   None,
#   'Fort Lee',
#   'NJ',
#   '70246302',
#   -39.5,
#   '2008-04-21',
#   32),
#  (100,
#   'Jacobs',
#   'Richard',
#   'G.',
#   '14337 Tawya Rd',
#   None,
#   'Apple Valley',
#   'CA',
#   '923075545',
#   -1000,
#   '2008-04-21',
#   32),
#  (101,
#   'Aaronson',
#   'Rebecca',
#   None,
#   '2000 Village Green Dr Apt 12',
#   None,
#   'Mill Creek',
#   'WA',
#   '980125787',
#   100,
#   '2008-02-08',
#   34),
#  (102,
#   'Aarons',
#   'Elaine',
#   None,
#   '481 Buck Island Rd Apt 17A',
#   'APT 17A',
#   'West Yarmouth',
#   'MA',
#   '26733300',
#   25,
#   '2008-02-26',
#   34),
#  (103,
#   'Aarons',
#   'Elaine',
#   None,
#   '481 Buck Island Rd Apt 17A',
#   'APT 17A',
#   'West Yarmouth',
#   'MA',
#   '26733300',
#   70,
#   '2008-02-25',
#   34),
#  (104,
#   'Aarons',
#   'Elaine',
#   None,
#   '481 Buck Island Rd Apt 17A',
#   'APT 17A',
#   'West Yarmouth',
#   'MA',
#   '26733300',
#   100,
#   '2008-02-08',
#   34),
#  (105,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   50,
#   '2008-02-29',
#   34),
#  (106,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-29',
#   34),
#  (107,
#   'Aaronson',
#   'Rebecca',
#   None,
#   '2000 Village Green Dr Apt 12',
#   None,
#   'Mill Creek',
#   'WA',
#   '980125787',
#   100,
#   '2008-02-14',
#   34),
#  (108,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-24',
#   34),
#  (109,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-22',
#   34),
#  (110,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-17',
#   34),
#  (111,
#   'Reid',
#   'Elizabeth',
#   None,
#   '73 W Patent Rd',
#   'OPHIR FARM NORTH',
#   'Bedford Hills',
#   'NY',
#   '105072222',
#   -350,
#   '2008-08-28',
#   34),
#  (112,
#   'Reich',
#   'Thomas',
#   None,
#   '499 Park Ave',
#   None,
#   'New York',
#   'NY',
#   '100221240',
#   -2300,
#   '2008-08-28',
#   34),
#  (113,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-08',
#   34),
#  (114,
#   'Aaron',
#   'Shirley',
#   None,
#   '101 Cherry Ave',
#   None,
#   'Havana',
#   'FL',
#   '323331311',
#   100,
#   '2008-02-03',
#   34),
#  (115,
#   'Aaron',
#   'Sharron',
#   None,
#   '1804 E Montgomery St',
#   None,
#   'Broken Arrow',
#   'OK',
#   '740121840',
#   500,
#   '2008-02-09',
#   34),
#  (116,
#   'Aaron',
#   'Patricia',
#   None,
#   '418 NW 35th St',
#   None,
#   'Oklahoma City',
#   'OK',
#   '731188602',
#   200,
#   '2008-02-26',
#   34),
#  (117,
#   'Aaron',
#   'Patricia',
#   None,
#   '418 NW 35th St',
#   None,
#   'Oklahoma City',
#   'OK',
#   '731188602',
#   100,
#   '2008-02-12',
#   34),
#  (118,
#   'Aaron',
#   'Jim',
#   None,
#   '2178 Fairway Cir',
#   None,
#   'Canton',
#   'MI',
#   '481885097',
#   300,
#   '2008-02-07',
#   34),
#  (119,
#   'Aaron',
#   'Jim',
#   None,
#   '2178 Fairway Cir',
#   None,
#   'Canton',
#   'MI',
#   '481885097',
#   200,
#   '2008-02-29',
#   34),
#  (120,
#   'Aaron',
#   'Carole',
#   None,
#   'PO Box 1806',
#   None,
#   'Ogunquit',
#   'ME',
#   '39071806',
#   70,
#   '2008-02-29',
#   34),
#  (121,
#   'Aaron',
#   'Carole',
#   None,
#   'PO Box 1806',
#   None,
#   'Ogunquit',
#   'ME',
#   '39071806',
#   50,
#   '2008-02-07',
#   34),
#  (122,
#   'Aaron',
#   'Carole',
#   None,
#   'PO Box 1806',
#   None,
#   'Ogunquit',
#   'ME',
#   '39071806',
#   100,
#   '2008-02-03',
#   34),
#  (123,
#   'Aaron',
#   'Barbara',
#   None,
#   '2298 Pacific Ave # 6',
#   None,
#   'San Francisco',
#   'CA',
#   '941151435',
#   1000,
#   '2008-02-11',
#   34),
#  (124,
#   'Aanonsen',
#   'Lin',
#   None,
#   '897 Raymond Ave',
#   None,
#   'Saint Paul',
#   'MN',
#   '551141508',
#   250,
#   '2008-02-21',
#   34),
#  (125,
#   'Aanonsen',
#   'Lin',
#   None,
#   '897 Raymond Ave',
#   None,
#   'Saint Paul',
#   'MN',
#   '551141508',
#   100,
#   '2008-02-08',
#   34),
#  (126,
#   'BOURNE',
#   'TRAVIS',
#   None,
#   'LAGE KAART 77',
#   None,
#   'BRASSCHATT',
#   None,
#   '2930',
#   -500,
#   '2008-11-20',
#   35),
#  (127,
#   'SECRIST',
#   'BRIAN',
#   'L.',
#   '3 MULE DEER TRAIL',
#   None,
#   'LITTLETON',
#   'CO',
#   '801275722',
#   -1000,
#   '2008-04-07',
#   35),
#  (128,
#   'TOLLESTRUP',
#   'TRAVIS',
#   'W.',
#   '16331 WINECREEK RD.',
#   None,
#   'SAN DIEGO',
#   'CA',
#   '92127',
#   -1000,
#   '2008-05-15',
#   35),
#  (129,
#   'ACCORD',
#   'DEAN',
#   'C.',
#   '8813 ROBINSON RIDGE ROAD',
#   None,
#   'LAS VEGAS',
#   'NV',
#   '891175812',
#   500,
#   '2007-07-13',
#   35),
#  (130,
#   'ABTS',
#   'HENRY',
#   None,
#   'P. O. BOX 7299',
#   None,
#   'INCLINE VILLAGE',
#   'NV',
#   '894527299',
#   100,
#   '2007-07-13',
#   35),
#  (131,
#   'ABSHIER',
#   'LANNY',
#   None,
#   '14191 S.E. HIGHWAY 301',
#   None,
#   'SUMMERFIELD',
#   'FL',
#   '34491',
#   500,
#   '2007-09-25',
#   35),
#  (132,
#   'ABSHIER',
#   'DIANA',
#   None,
#   '14191 S.E. HIGHWAY 301',
#   None,
#   'SUMMERFIELD',
#   'FL',
#   '34491',
#   500,
#   '2007-09-25',
#   35),
#  (133,
#   'ABREU',
#   'KEVIN',
#   'M.',
#   '1305 GARDEN GLEN LANE',
#   None,
#   'PEARLAND',
#   'TX',
#   '775816547',
#   50,
#   '2007-09-30',
#   35),
#  (134,
#   'ABREU',
#   'KEVIN',
#   'M.',
#   '1305 GARDEN GLEN LANE',
#   None,
#   'PEARLAND',
#   'TX',
#   '775816547',
#   150,
#   '2007-08-09',
#   35),
#  (135,
#   'ABREU',
#   'KEVIN',
#   'M.',
#   '1305 GARDEN GLEN LANE',
#   None,
#   'PEARLAND',
#   'TX',
#   '775816547',
#   50,
#   '2007-07-19',
#   35),
#  (136,
#   'ABRAMOWITZ',
#   'NIRA',
#   None,
#   '411 HARBOR ROAD',
#   None,
#   'SOUTHPORT',
#   'CT',
#   '68901376',
#   2300,
#   '2007-09-14',
#   35),
#  (137,
#   'ABRAMS',
#   'MICHAEL',
#   None,
#   '7910 WOODMONT AVENUE',
#   None,
#   'BETHESDA',
#   'MD',
#   '208143002',
#   250,
#   '2007-09-29',
#   35),
#  (138,
#   'ABRAMOWITZ',
#   'KEN',
#   None,
#   '200 CENTRAL PARK S.',
#   'APARTMENT 31A',
#   'NEW YORK',
#   'NY',
#   '100191448',
#   300,
#   '2007-09-11',
#   35),
#  (139,
#   'ABOUBAKARE',
#   'NASAR',
#   None,
#   '1400 SAN MIGUEL DRIVE',
#   None,
#   'CORONA DEL MAR',
#   'CA',
#   '926251300',
#   1000,
#   '2007-07-09',
#   35),
#  (140,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   75,
#   '2007-09-25',
#   35),
#  (141,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-09-17',
#   35),
#  (142,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   75,
#   '2007-08-31',
#   35),
#  (143,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   75,
#   '2007-08-14',
#   35),
#  (144,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-08-06',
#   35),
#  (145,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-07-10',
#   35),
#  (146,
#   'ABDELLA',
#   'THOMAS',
#   'M.',
#   '4231 MONUMENT WALL WAY #340',
#   None,
#   'FAIRFAX',
#   'VA',
#   '220308440',
#   50,
#   '2007-09-30',
#   35),
#  (147,
#   'ABBOTT',
#   'WELDON',
#   'S.',
#   '777 EAST SOUTH TEMPLE  4E',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841021269',
#   100,
#   '2007-09-29',
#   35),
#  (148,
#   'ABBOTT',
#   'WELDON',
#   'S.',
#   '777 EAST SOUTH TEMPLE  4E',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841021269',
#   50,
#   '2007-08-09',
#   35),
#  (149,
#   'ABBOTT',
#   'GERALD',
#   'F.',
#   '389 BENEFIT STREET',
#   None,
#   'PROVIDENCE',
#   'RI',
#   '29032946',
#   100,
#   '2007-09-15',
#   35),
#  (150,
#   'ABBOTT',
#   'GERALD',
#   'F.',
#   '389 BENEFIT STREET',
#   None,
#   'PROVIDENCE',
#   'RI',
#   '29032946',
#   100,
#   '2007-08-15',
#   35),
#  (151,
#   'ABEDIN',
#   'ZAINUL',
#   None,
#   '715 N. CENTRAL AVENUE',
#   'SUITE 212',
#   'GLENDALE',
#   'CA',
#   '912031164',
#   500,
#   '2008-01-21',
#   37),
#  (152,
#   'ABBOTT',
#   'SYBIL',
#   'F.',
#   '446 GAMES DRIVE',
#   None,
#   'RENO',
#   'NV',
#   '895093326',
#   75,
#   '2008-01-08',
#   37),
#  (153,
#   'ABBOTT',
#   'SYBIL',
#   'F.',
#   '446 GAMES DRIVE',
#   None,
#   'RENO',
#   'NV',
#   '895093326',
#   50,
#   '2008-01-08',
#   37),
#  (154,
#   'ABBOTT',
#   'RONALD',
#   'LEANDER',
#   '5453 HAWTHORNE STREET',
#   None,
#   'MONTCLAIR',
#   'CA',
#   '917632551',
#   200,
#   '2008-01-31',
#   37),
#  (155,
#   'ABBOTT',
#   'RONALD',
#   'LEANDER',
#   '5453 HAWTHORNE STREET',
#   None,
#   'MONTCLAIR',
#   'CA',
#   '917632551',
#   100,
#   '2008-01-08',
#   37),
#  (156,
#   'ABBOTT',
#   'ROBERT',
#   'A.',
#   '3061 LOREE ROAD',
#   None,
#   'DECKERVILLE',
#   'MI',
#   '484279763',
#   500,
#   '2008-01-21',
#   37),
#  (157,
#   'ABBOTT',
#   'MIKE',
#   'E.',
#   '4516 OSPREY LNDG',
#   None,
#   'NICEVILLE',
#   'FL',
#   '325786810',
#   1000,
#   '2008-01-15',
#   37),
#  (158,
#   'ABBOT',
#   'DAVID',
#   'M.',
#   '56 SALEM STREET',
#   None,
#   'ANDOVER',
#   'MA',
#   '18102114',
#   200,
#   '2008-01-21',
#   37),
#  (159,
#   'ABBO',
#   'PAULINE',
#   'MORENCY',
#   '10720 JACOB LANE',
#   None,
#   'WHITE LAKE',
#   'MI',
#   '483862274',
#   35,
#   '2008-01-07',
#   37),
#  (160,
#   'ABATE',
#   'MARIA',
#   'ELENA',
#   '1291 NIGHTINGALE AVENUE',
#   None,
#   'MIAMI SPRINGS',
#   'FL',
#   '331663832',
#   2600,
#   '2008-01-25',
#   37),
#  (161,
#   'ABAIR',
#   'PETER',
#   None,
#   '40 EVANS STREET',
#   None,
#   'WATERTOWN',
#   'MA',
#   '24722150',
#   25,
#   '2008-01-09',
#   37),
#  (162,
#   'ABACHERLI',
#   'SHIRLEY',
#   'M.',
#   '29875 NEWPORT ROAD',
#   None,
#   'MENIFEE',
#   'CA',
#   '925849524',
#   150,
#   '2008-01-28',
#   37),
#  (163,
#   'AARONS',
#   'CHARLES',
#   None,
#   '1730 SHORE DRIVE',
#   None,
#   'ANCHORAGE',
#   'AK',
#   '995153207',
#   300,
#   '2008-01-30',
#   37),
#  (164,
#   'AARONS',
#   'CHARLES',
#   None,
#   '1730 SHORE DRIVE',
#   None,
#   'ANCHORAGE',
#   'AK',
#   '995153207',
#   410,
#   '2008-01-15',
#   37),
#  (165,
#   'AARONS',
#   'CHARLES',
#   None,
#   '1730 SHORE DRIVE',
#   None,
#   'ANCHORAGE',
#   'AK',
#   '995153207',
#   500,
#   '2008-01-09',
#   37),
#  (166,
#   'ABEL',
#   'JOHN',
#   'H.',
#   '422 THOMAS STREET',
#   None,
#   'BETHLEHEM',
#   'PA',
#   '180153316',
#   200,
#   '2008-01-22',
#   37),
#  (167,
#   'ABEL',
#   'MARLING',
#   'L.',
#   '14 HANGING MOSS LANE',
#   None,
#   'GREENVILLE',
#   'SC',
#   '296155069',
#   100,
#   '2008-01-22',
#   37),
#  (168,
#   'ABEL',
#   'RUDOLPH',
#   None,
#   '4532 OCEAN BLVD.',
#   '# 108',
#   'SARASOTA',
#   'FL',
#   '342421337',
#   100,
#   '2008-01-08',
#   37),
#  (169,
#   'ABELE',
#   'RODNEY',
#   None,
#   '3620 METAIRIE HEIGHTS AVENUE',
#   None,
#   'METAIRIE',
#   'LA',
#   '700021823',
#   500,
#   '2008-01-15',
#   37),
#  (170,
#   'ABERCROMBIE',
#   'DENIS',
#   None,
#   '11811 WATER OAK CT',
#   None,
#   'MAGNOLIA',
#   'TX',
#   '773546270',
#   500,
#   '2008-01-30',
#   37),
#  (171,
#   'ABESHAUS',
#   'MERRILL',
#   'M.',
#   '1801 N. HEREFORD DRIVE',
#   None,
#   'FLAGSTAFF',
#   'AZ',
#   '860011121',
#   120,
#   '2008-01-16',
#   37),
#  (172,
#   'ABRAHAM',
#   'GEORGE',
#   None,
#   'P.O. BOX 1504',
#   None,
#   'LAKE CHARLES',
#   'LA',
#   '706021504',
#   800,
#   '2008-01-17',
#   37),
#  (173,
#   'ABRAHAMSON',
#   'PETER',
#   'J.',
#   '1030 W. ROSCOE STREET',
#   None,
#   'CHICAGO',
#   'IL',
#   '606572207',
#   50,
#   '2008-01-25',
#   37),
#  (174,
#   'ABRAHAM',
#   'SALEM',
#   'A.',
#   'P.O. BOX 7',
#   None,
#   'CANADIAN',
#   'TX',
#   '790140007',
#   1000,
#   '2008-01-17',
#   37),
#  (175,
#   'ABRAHAM',
#   'SALEM',
#   'A.',
#   'P.O. BOX 7',
#   None,
#   'CANADIAN',
#   'TX',
#   '790140007',
#   1300,
#   '2008-01-30',
#   37)]

# %%
out=make_query("SELECT * FROM contributors WHERE state='VA' AND amount < 400;")
make_frame(out)
# Out:
#     id  last_name first_name middle_name                     street_1  \
# 0   28   Buckheit      Bruce        None                8904 KAREN DR
# 1   78  Ranganath      Anoop        None           2507 Willard Drive
# 2   89  Perreault     Louise        None    503 Brockridge Hunt Drive
# 3  146    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  candidate_id
# 0     None          FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 1     None  Charlottesville    VA      22903 -100.00  2008-04-21            32
# 2     None          Hampton    VA      23666  -34.08  2008-04-21            32
# 3     None          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %% [markdown]
# ## House Bios

# %%
https://xml.house.gov/MemberData/MemberData.xml
# Out:
#   File "<ipython-input-13-0714b07055fd>", line 1
#     https://xml.house.gov/MemberData/MemberData.xml
#            ^
# SyntaxError: invalid syntax

# %%
party = ntree.xpath('//party/text()')
yea = ntree.xpath('//yea-total/text()')
nay = ntree.xpath('//nay-total/text()')
present = ntree.xpath('//present-total/text()')
not_voting = ntree.xpath('//not-voting-total/text()')

party = [*party, 'Total']

# %%
congress = ntree.xpath('//congress/text()')
rollnum = ntree.xpath('//rollcall-num/text()')

congress = [*congress, *congress, *congress, *congress]
rollnum = [*rollnum, *rollnum, *rollnum, *rollnum]

# %%
votingdf = pd.DataFrame({'congress':congress, 'rollnum':rollnum, 'party':party, 'yea':yea, 'nay':nay, 'present':present, 'not_voting':not_voting})
votingdf = votingdf[['congress', 'rollnum', 'party', 'yea', 'nay', 'present', 'not_voting']]

# %%
votingdf
# Out:
#   congress rollnum        party  yea  nay present not_voting
# 0      115     699   Republican  224   12       0          3
# 1      115     699   Democratic    0  189       0          4
# 2      115     699  Independent    0    0       0          0
# 3      115     699        Total  224  201       0          7

# %%
votingdf_flat = pd.melt(votingdf, id_vars=['congress','rollnum','party'], 
                        value_vars=['yea','nay','present','not_voting'], 
                        var_name='vote_type', value_name='vote_count')

# %%
votingdf_flat

# %%
votingdf_699 = votingdf

# %%
votingdf_692
# Out:
#   congress rollnum        party  yea  nay present not_voting
# 0      115     692   Republican  227   12       0          0
# 1      115     692   Democratic    0  191       0          2
# 2      115     692  Independent    0    0       0          0
# 3      115     692        Total  227  203       0          2

# %%
votingdf_699
# Out:
#   congress rollnum        party  yea  nay present not_voting
# 0      115     699   Republican  224   12       0          3
# 1      115     699   Democratic    0  189       0          4
# 2      115     699  Independent    0    0       0          0
# 3      115     699        Total  224  201       0          7

# %%
# binary can never represent 0.1, which is why it is numerically unstable
count = 0

# %%
for _ in range(1000):
    count += .1
count
# Out:
# 99.9999999999986
